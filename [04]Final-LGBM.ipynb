# %%
from types import SimpleNamespace
import pandas as pd
import numpy as np

# %%
### 학습용 데이터 로드
def loadEvaluationData():
    label = pd.read_csv("data/Participant_table_labeled.csv")
    ehr = pd.read_csv("data/EHR.csv")
    label = label[label["risk"] != -1]
    label = label[["Participant ID", "risk"]]

    lid = list(label["Participant ID"])
    eid = list(ehr["Participant ID"])

    if all(x == y for x, y in zip(lid, eid)) == True:
        label = np.array(label["risk"])
        ehr = np.array(ehr.drop(columns = ["Participant ID"]))
    else:
        raise ValueError("Participant IDs do not match across label and ehr datasets.")
    print(ehr.shape)
    print(label.shape)
    return ehr, label

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler
import pickle

test_size = 0.2
random_seed = 42

ehr, label = loadEvaluationData()


tab_X_train, tab_X_val, y_train, y_val = train_test_split(ehr, label, test_size=0.2, random_state=random_seed)

imputer = KNNImputer(n_neighbors=1000)
scaler = StandardScaler()
    
tab_X_train_scaled = scaler.fit_transform(tab_X_train)
tab_X_val_scaled = scaler.transform(tab_X_val)

tab_X_train_imputed = imputer.fit_transform(tab_X_train_scaled)
tab_X_val_imputed = imputer.transform(tab_X_val_scaled)

with open('src/preprocessor/scaler_LGBM.pkl','wb') as sc:
    pickle.dump(scaler, sc)
with open('src/preprocessor/imputer_LGBM.pkl','wb') as im:
    pickle.dump(imputer, im)


continuous_cols_list = [['Age at recruitment_x'], ['Urea | Instance 0_x'], ['Creatinine | Instance 0_x'], ['Haemoglobin concentration | Instance 0'], ['White blood cell (leukocyte) count | Instance 0_x'], ['Albumin | Instance 0_x'], ['Platelet count | Instance 0_x'], ['Platelet distribution width | Instance 0'], ['Diastolic blood pressure_x'], ['Diastolic blood pressure2_x'], ['Haematocrit percentage | Instance 0'], ['Lymphocyte percentage | Instance 0'], ['Neutrophill percentage | Instance 0'], ['Red blood cell (erythrocyte) count | Instance 0'], 
                    ['Alanine aminotransferase | Instance 0'], ['Albumin | Instance 0_y'], ['Alkaline phosphatase | Instance 0'], ['Apolipoprotein A | Instance 0'], ['Apolipoprotein B | Instance 0'], ['Aspartate aminotransferase | Instance 0'], ['C-reactive protein | Instance 0'], ['Calcium | Instance 0'], ['Cholesterol | Instance 0'], ['Cystatin C | Instance 0'], ['Direct bilirubin | Instance 0'], ['Gamma glutamyltransferase | Instance 0'], ['Glucose | Instance 0'], ['Glycated haemoglobin (HbA1c) | Instance 0'], ['HDL cholesterol | Instance 0'],
                    ['IGF-1 | Instance 0'], ['LDL direct | Instance 0'], ['Lipoprotein A | Instance 0'], ['Phosphate | Instance 0'], ['Total bilirubin | Instance 0'], ['Total protein | Instance 0'], ['Triglycerides | Instance 0'], ['Summed MET minutes per week for all activity | Instance 0'], ['Systolic blood pressure'], ['Systolic blood pressure2'], ['Pulse rate'], ['Pulse rate2'], ['CKMT1A_CKMT1B;Creatine kinase U-type'], ['NTproBNP;N-terminal prohormone of brain natriuretic peptide'], ['NBL1;Neuroblastoma suppressor of tumorigenicity 1'],
                    ['LGALS3;Galectin-3'], ['Urate | Instance 0'], ['Vitamin D | Instance 0'], ['Microalbumin in urine | Instance 0'], ['Standing height | Instance 0'], ['Weight | Instance 0'], ['Body mass index (BMI) | Instance 0']]

categorical_cols_list = [['Sex_x_encoded'], ['Ethnic background | Instance 0_encoded'], ['Sleeplessness / insomnia | Instance 0_encoded'], ['Smoking status | Instance 0_x_encoded'], ['Processed meat intake | Instance 0_encoded'], ['Coffee intake | Instance 0_encoded'], ['Alcohol drinker status | Instance 0_x_encoded'], ['Alcohol intake frequency. | Instance 0_encoded'], ['Pace-maker | Instance 0_encoded']]

continuous_cols = []
categorical_cols = []

for i in continuous_cols_list:
    continuous_cols.append(i[0])

for i in categorical_cols_list:
    categorical_cols.append(i[0])

cols = []
for col_list in continuous_cols_list + categorical_cols_list:
    cols.extend(col_list)

data = pd.DataFrame(tab_X_train_imputed, columns = cols, dtype = float)
X_test = pd.DataFrame(tab_X_val_imputed, columns = cols, dtype = float)
label = np.array(y_train)
y_test = np.array(y_val)
# Out:
# (8556, 60)
# (8556,)

# %%
import importlib

def prepare_config(target_config: str) -> SimpleNamespace:
    configlib = importlib.import_module('src.config')
    config = getattr(configlib, target_config)
    
    config.model.out_dim = 2
    
    config.experiment.metric = "f1_score"
    # config.experiment.metric = "accuracy_score"
    # config.experiment.metric = "recall_score"
    config.experiment.metric_params = []
    config.experiment.data_config = "EHR"
    config.experiment.optuna.direction = 'maximize'
    config.experiment.random_seed = random_seed
    config.experiment.task = "binary"
    
    config.experiment.optuna.n_trials = 100
    
    config.experiment.calibrator = "HistogramBinning"
    
    config.experiment.KFold = 5
    config.experiment.early_stopping_patience = 30
    config.dice.backend = "sklearn"
    
    config.experiment.fast_dev_run = False
    return config

# %%
config = prepare_config('lgbm_config')

# %%
from src.models import BaseModel
from src.misc.eval_metric import EvalMetric
from sklearn.metrics import f1_score, recall_score, accuracy_score, confusion_matrix, accuracy_score
from sklearn.metrics import roc_auc_score, recall_score, average_precision_score
from typing import Type

class EHREvalMetric(EvalMetric):
    def eval(self, model: Type[BaseModel], X_test: pd.DataFrame, y_test: np.array):
        preds_proba = model.predict_proba(X_test)
        preds = preds_proba.argmax(1)
        
        f1 = f1_score(y_test, preds)
        roc = roc_auc_score(y_test, preds_proba[:, 1])
        specificity = recall_score(np.logical_not(y_test) , np.logical_not(preds))
        sensitivity = recall_score(y_test, preds)
        accuracy = accuracy_score(y_test, preds)
        pr_auc = average_precision_score(y_test, preds_proba[:, 1])
        tn, fp, fn, tp = confusion_matrix(y_test, preds).ravel()
        ppv = tp / (tp + fp)
        npv = tn / (tn + fn)
        
        print("F1 Score: %.4f" % f1)
        print("ROC AUC Score: %.4f" % roc)
        print("Specificity Score: %.4f" % specificity)
        print("Sensitivity Score: %.4f" % sensitivity)
        print("Accuracy Score: %.4f" % accuracy)
        print("Precision Recall AUC Score: %.4f" % pr_auc)
        print("PPV Score: %.4f" % ppv)
        print("NPV Score: %.4f" % npv)

        return {
            "F1 Score" : f1,
            "ROC AUC Score" : roc,
            "Specificity Score" : specificity,
            "Sensitivity Score" : sensitivity,
            "Accuracy Score" : accuracy,
            "Precision Recall AUC Score" : pr_auc,
            "PPV Score" : ppv,
            "NPV Score" : npv
        }

# %%
from src.rias import RIAS
from src.models import LGBM
from raiutils.exceptions import UserConfigValidationException

rias = RIAS.prepare_rias(config, LGBM, data, label, continuous_cols, categorical_cols, True)

rias.train()

rias.init_calibrator()
rias.test(X_test, y_test, EHREvalMetric())
# Out:
# /usr/local/lib/python3.8/dist-packages/dice_ml/utils/exception.py:12: UserWarning: UserConfigValidationException will be deprecated from dice_ml.utils. Please import UserConfigValidationException from raiutils.exceptions.
#   warnings.warn("UserConfigValidationException will be deprecated from dice_ml.utils. "
# 2024-05-25 09:29:09.800652: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-25 09:29:10.546532: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [I 2024-05-25 09:29:10,988] A new study created in memory with name: no-name-f835c15c-3a61-4cfa-9c6e-0c0b0c58c05c
# [I 2024-05-25 09:29:19,643] Trial 0 finished with value: 0.0 and parameters: {'num_leaves': 1686, 'n_estimators': 2853, 'learning_rate': 0.007587945476302646, 'max_depth': 31, 'scale_pos_weight': 18}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:29:37,463] Trial 1 finished with value: 0.0 and parameters: {'num_leaves': 877, 'n_estimators': 183, 'learning_rate': 0.008795585311974417, 'max_depth': 31, 'scale_pos_weight': 72}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:29:53,898] Trial 2 finished with value: 0.0 and parameters: {'num_leaves': 376, 'n_estimators': 2911, 'learning_rate': 0.008491983767203797, 'max_depth': 13, 'scale_pos_weight': 20}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:30:27,954] Trial 3 finished with value: 0.0 and parameters: {'num_leaves': 978, 'n_estimators': 919, 'learning_rate': 0.005722807884690141, 'max_depth': 23, 'scale_pos_weight': 31}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:30:58,336] Trial 4 finished with value: 0.0 and parameters: {'num_leaves': 2564, 'n_estimators': 427, 'learning_rate': 0.0036293018368169635, 'max_depth': 20, 'scale_pos_weight': 47}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:31:15,343] Trial 5 finished with value: 0.0 and parameters: {'num_leaves': 3205, 'n_estimators': 607, 'learning_rate': 0.005628109945722505, 'max_depth': 31, 'scale_pos_weight': 7}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:31:42,901] Trial 6 finished with value: 0.0 and parameters: {'num_leaves': 2548, 'n_estimators': 520, 'learning_rate': 0.0015854643368675156, 'max_depth': 48, 'scale_pos_weight': 97}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:31:55,394] Trial 7 finished with value: 0.0 and parameters: {'num_leaves': 3291, 'n_estimators': 921, 'learning_rate': 0.001879049026057455, 'max_depth': 35, 'scale_pos_weight': 46}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:32:01,832] Trial 8 finished with value: 0.0 and parameters: {'num_leaves': 751, 'n_estimators': 1491, 'learning_rate': 0.0013094966900369656, 'max_depth': 46, 'scale_pos_weight': 28}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:32:10,594] Trial 9 finished with value: 0.0 and parameters: {'num_leaves': 2751, 'n_estimators': 942, 'learning_rate': 0.0056806121906002975, 'max_depth': 29, 'scale_pos_weight': 21}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:32:11,186] Trial 10 finished with value: 0.0 and parameters: {'num_leaves': 1686, 'n_estimators': 2800, 'learning_rate': 0.009725833997090795, 'max_depth': 3, 'scale_pos_weight': 4}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:32:16,288] Trial 11 finished with value: 0.0 and parameters: {'num_leaves': 1596, 'n_estimators': 2454, 'learning_rate': 0.007759918276625106, 'max_depth': 39, 'scale_pos_weight': 80}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:32:19,895] Trial 12 finished with value: 0.0 and parameters: {'num_leaves': 1499, 'n_estimators': 2095, 'learning_rate': 0.007810886706853567, 'max_depth': 39, 'scale_pos_weight': 73}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:32:21,546] Trial 13 finished with value: 0.0 and parameters: {'num_leaves': 1188, 'n_estimators': 1724, 'learning_rate': 0.009985711586801754, 'max_depth': 16, 'scale_pos_weight': 66}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:32:24,860] Trial 14 finished with value: 0.0 and parameters: {'num_leaves': 2098, 'n_estimators': 48, 'learning_rate': 0.007252785471204158, 'max_depth': 26, 'scale_pos_weight': 64}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:32:28,252] Trial 15 finished with value: 0.0 and parameters: {'num_leaves': 3874, 'n_estimators': 1449, 'learning_rate': 0.006803150824063096, 'max_depth': 34, 'scale_pos_weight': 90}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:32:30,939] Trial 16 finished with value: 0.0 and parameters: {'num_leaves': 311, 'n_estimators': 2337, 'learning_rate': 0.008625632182518037, 'max_depth': 44, 'scale_pos_weight': 53}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:32:33,247] Trial 17 finished with value: 0.0 and parameters: {'num_leaves': 2021, 'n_estimators': 49, 'learning_rate': 0.009010287147410567, 'max_depth': 9, 'scale_pos_weight': 38}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:32:35,408] Trial 18 finished with value: 0.0 and parameters: {'num_leaves': 827, 'n_estimators': 1874, 'learning_rate': 0.006988846367852636, 'max_depth': 24, 'scale_pos_weight': 59}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:32:38,880] Trial 19 finished with value: 0.0 and parameters: {'num_leaves': 1270, 'n_estimators': 2547, 'learning_rate': 0.006505501157030063, 'max_depth': 38, 'scale_pos_weight': 82}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:32:42,713] Trial 20 finished with value: 0.0 and parameters: {'num_leaves': 1847, 'n_estimators': 1298, 'learning_rate': 0.009017236599572662, 'max_depth': 30, 'scale_pos_weight': 12}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:32:44,384] Trial 21 finished with value: 0.0 and parameters: {'num_leaves': 377, 'n_estimators': 2915, 'learning_rate': 0.008191348195119583, 'max_depth': 15, 'scale_pos_weight': 19}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:32:46,036] Trial 22 finished with value: 0.0 and parameters: {'num_leaves': 631, 'n_estimators': 2962, 'learning_rate': 0.008468186191576138, 'max_depth': 17, 'scale_pos_weight': 37}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:32:46,483] Trial 23 finished with value: 0.0 and parameters: {'num_leaves': 1215, 'n_estimators': 2667, 'learning_rate': 0.009233564587117514, 'max_depth': 6, 'scale_pos_weight': 19}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:32:47,406] Trial 24 finished with value: 0.0 and parameters: {'num_leaves': 566, 'n_estimators': 2017, 'learning_rate': 0.007740806981547969, 'max_depth': 9, 'scale_pos_weight': 13}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:32:49,911] Trial 25 finished with value: 0.0 and parameters: {'num_leaves': 978, 'n_estimators': 2121, 'learning_rate': 0.008489257462965725, 'max_depth': 20, 'scale_pos_weight': 29}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:32:51,238] Trial 26 finished with value: 0.0 and parameters: {'num_leaves': 1353, 'n_estimators': 2395, 'learning_rate': 0.009264950636128644, 'max_depth': 12, 'scale_pos_weight': 39}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:32:53,995] Trial 27 finished with value: 0.0 and parameters: {'num_leaves': 958, 'n_estimators': 1203, 'learning_rate': 0.0064253597754981235, 'max_depth': 34, 'scale_pos_weight': 73}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:32:56,751] Trial 28 finished with value: 0.0 and parameters: {'num_leaves': 616, 'n_estimators': 2615, 'learning_rate': 0.007581946172434739, 'max_depth': 26, 'scale_pos_weight': 54}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:32:59,937] Trial 29 finished with value: 0.0 and parameters: {'num_leaves': 2342, 'n_estimators': 1755, 'learning_rate': 0.008109596525607473, 'max_depth': 22, 'scale_pos_weight': 26}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:33:03,483] Trial 30 finished with value: 0.0 and parameters: {'num_leaves': 1014, 'n_estimators': 2738, 'learning_rate': 0.004840887748074207, 'max_depth': 28, 'scale_pos_weight': 34}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:33:06,380] Trial 31 finished with value: 0.0 and parameters: {'num_leaves': 484, 'n_estimators': 291, 'learning_rate': 0.004883876579692242, 'max_depth': 22, 'scale_pos_weight': 16}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:33:09,065] Trial 32 finished with value: 0.0 and parameters: {'num_leaves': 800, 'n_estimators': 714, 'learning_rate': 0.007259303245841402, 'max_depth': 31, 'scale_pos_weight': 8}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:33:13,812] Trial 33 finished with value: 0.0 and parameters: {'num_leaves': 1427, 'n_estimators': 405, 'learning_rate': 0.006129149280667665, 'max_depth': 42, 'scale_pos_weight': 24}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:33:16,199] Trial 34 finished with value: 0.0 and parameters: {'num_leaves': 1133, 'n_estimators': 307, 'learning_rate': 0.007247725610746156, 'max_depth': 19, 'scale_pos_weight': 48}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:33:21,399] Trial 35 finished with value: 0.0 and parameters: {'num_leaves': 1843, 'n_estimators': 805, 'learning_rate': 0.008472114671002914, 'max_depth': 32, 'scale_pos_weight': 33}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:33:22,928] Trial 36 finished with value: 0.0 and parameters: {'num_leaves': 2395, 'n_estimators': 1093, 'learning_rate': 0.0059436805090793635, 'max_depth': 13, 'scale_pos_weight': 46}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:33:31,360] Trial 37 finished with value: 0.0 and parameters: {'num_leaves': 321, 'n_estimators': 579, 'learning_rate': 0.005222138676310908, 'max_depth': 23, 'scale_pos_weight': 11}. Best is trial 0 with value: 0.0.
# [I 2024-05-25 09:33:39,239] Trial 38 finished with value: 0.04915254237288136 and parameters: {'num_leaves': 2790, 'n_estimators': 975, 'learning_rate': 0.009582197489532705, 'max_depth': 26, 'scale_pos_weight': 3}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:33:43,103] Trial 39 finished with value: 0.0 and parameters: {'num_leaves': 2891, 'n_estimators': 1064, 'learning_rate': 0.009617722342933956, 'max_depth': 36, 'scale_pos_weight': 100}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:33:47,111] Trial 40 finished with value: 0.0 and parameters: {'num_leaves': 3222, 'n_estimators': 2213, 'learning_rate': 0.009555792493590932, 'max_depth': 49, 'scale_pos_weight': 4}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:33:51,292] Trial 41 finished with value: 0.0 and parameters: {'num_leaves': 3499, 'n_estimators': 808, 'learning_rate': 0.008886576736597618, 'max_depth': 26, 'scale_pos_weight': 23}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:33:54,562] Trial 42 finished with value: 0.0 and parameters: {'num_leaves': 761, 'n_estimators': 1613, 'learning_rate': 0.009866869728132461, 'max_depth': 29, 'scale_pos_weight': 3}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:33:58,357] Trial 43 finished with value: 0.0 and parameters: {'num_leaves': 2928, 'n_estimators': 1358, 'learning_rate': 0.00803721053781939, 'max_depth': 32, 'scale_pos_weight': 15}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:34:02,040] Trial 44 finished with value: 0.0 and parameters: {'num_leaves': 2620, 'n_estimators': 1023, 'learning_rate': 0.009467947709423377, 'max_depth': 18, 'scale_pos_weight': 8}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:34:05,046] Trial 45 finished with value: 0.0 and parameters: {'num_leaves': 1562, 'n_estimators': 209, 'learning_rate': 0.008623962876994249, 'max_depth': 24, 'scale_pos_weight': 30}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:34:07,633] Trial 46 finished with value: 0.0 and parameters: {'num_leaves': 1082, 'n_estimators': 486, 'learning_rate': 0.00989541743347075, 'max_depth': 27, 'scale_pos_weight': 92}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:34:11,913] Trial 47 finished with value: 0.0 and parameters: {'num_leaves': 1831, 'n_estimators': 669, 'learning_rate': 0.009015201724026794, 'max_depth': 37, 'scale_pos_weight': 43}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:34:15,755] Trial 48 finished with value: 0.0 and parameters: {'num_leaves': 3433, 'n_estimators': 872, 'learning_rate': 0.007493106977785241, 'max_depth': 42, 'scale_pos_weight': 20}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:34:19,681] Trial 49 finished with value: 0.0 and parameters: {'num_leaves': 2199, 'n_estimators': 2822, 'learning_rate': 0.008162335085159931, 'max_depth': 33, 'scale_pos_weight': 8}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:34:23,366] Trial 50 finished with value: 0.0 and parameters: {'num_leaves': 3029, 'n_estimators': 1558, 'learning_rate': 0.008870935115729511, 'max_depth': 30, 'scale_pos_weight': 68}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:34:25,322] Trial 51 finished with value: 0.0 and parameters: {'num_leaves': 2646, 'n_estimators': 160, 'learning_rate': 0.004126602018815965, 'max_depth': 15, 'scale_pos_weight': 42}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:34:30,267] Trial 52 finished with value: 0.0 and parameters: {'num_leaves': 2475, 'n_estimators': 445, 'learning_rate': 0.0029629827393640997, 'max_depth': 21, 'scale_pos_weight': 77}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:34:33,225] Trial 53 finished with value: 0.0 and parameters: {'num_leaves': 2260, 'n_estimators': 113, 'learning_rate': 0.006754319460128727, 'max_depth': 24, 'scale_pos_weight': 59}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:34:33,488] Trial 54 finished with value: 0.0 and parameters: {'num_leaves': 1996, 'n_estimators': 612, 'learning_rate': 0.009367443496319933, 'max_depth': 3, 'scale_pos_weight': 58}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:34:35,705] Trial 55 finished with value: 0.0 and parameters: {'num_leaves': 2795, 'n_estimators': 360, 'learning_rate': 0.007876277228310065, 'max_depth': 12, 'scale_pos_weight': 17}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:34:36,179] Trial 56 finished with value: 0.0 and parameters: {'num_leaves': 1716, 'n_estimators': 22, 'learning_rate': 0.008339198651601576, 'max_depth': 8, 'scale_pos_weight': 32}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:34:38,859] Trial 57 finished with value: 0.0 and parameters: {'num_leaves': 911, 'n_estimators': 2516, 'learning_rate': 0.00866801584816797, 'max_depth': 25, 'scale_pos_weight': 27}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:34:42,325] Trial 58 finished with value: 0.0 and parameters: {'num_leaves': 3083, 'n_estimators': 2946, 'learning_rate': 0.009987768393033579, 'max_depth': 28, 'scale_pos_weight': 12}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:34:45,364] Trial 59 finished with value: 0.0 and parameters: {'num_leaves': 532, 'n_estimators': 2815, 'learning_rate': 0.009182975306867396, 'max_depth': 19, 'scale_pos_weight': 49}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:34:46,920] Trial 60 finished with value: 0.0 and parameters: {'num_leaves': 705, 'n_estimators': 1285, 'learning_rate': 0.00789572174411117, 'max_depth': 14, 'scale_pos_weight': 23}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:34:51,727] Trial 61 finished with value: 0.0 and parameters: {'num_leaves': 3521, 'n_estimators': 558, 'learning_rate': 0.005662531698975025, 'max_depth': 34, 'scale_pos_weight': 7}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:34:55,016] Trial 62 finished with value: 0.0 and parameters: {'num_leaves': 3649, 'n_estimators': 909, 'learning_rate': 0.006331991471717228, 'max_depth': 30, 'scale_pos_weight': 85}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:34:58,692] Trial 63 finished with value: 0.0 and parameters: {'num_leaves': 1330, 'n_estimators': 745, 'learning_rate': 0.006972235591802159, 'max_depth': 28, 'scale_pos_weight': 14}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:35:03,092] Trial 64 finished with value: 0.0 and parameters: {'num_leaves': 3209, 'n_estimators': 255, 'learning_rate': 0.005825430824804037, 'max_depth': 35, 'scale_pos_weight': 18}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:35:07,110] Trial 65 finished with value: 0.0 and parameters: {'num_leaves': 2718, 'n_estimators': 1003, 'learning_rate': 0.006724784545680574, 'max_depth': 22, 'scale_pos_weight': 5}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:35:11,087] Trial 66 finished with value: 0.0 and parameters: {'num_leaves': 2510, 'n_estimators': 1124, 'learning_rate': 0.005267699013991316, 'max_depth': 31, 'scale_pos_weight': 10}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:35:14,952] Trial 67 finished with value: 0.0 and parameters: {'num_leaves': 3947, 'n_estimators': 343, 'learning_rate': 0.007564674010500355, 'max_depth': 17, 'scale_pos_weight': 37}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:35:18,671] Trial 68 finished with value: 0.0 and parameters: {'num_leaves': 443, 'n_estimators': 494, 'learning_rate': 0.006233593063987278, 'max_depth': 27, 'scale_pos_weight': 22}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:35:24,036] Trial 69 finished with value: 0.0 and parameters: {'num_leaves': 2001, 'n_estimators': 2675, 'learning_rate': 0.008654710946470662, 'max_depth': 40, 'scale_pos_weight': 25}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:35:26,055] Trial 70 finished with value: 0.0 and parameters: {'num_leaves': 866, 'n_estimators': 661, 'learning_rate': 0.008301000829603222, 'max_depth': 21, 'scale_pos_weight': 55}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:35:32,128] Trial 71 finished with value: 0.0 and parameters: {'num_leaves': 2835, 'n_estimators': 514, 'learning_rate': 0.0011690577190486902, 'max_depth': 50, 'scale_pos_weight': 94}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:35:39,026] Trial 72 finished with value: 0.0 and parameters: {'num_leaves': 2570, 'n_estimators': 3000, 'learning_rate': 0.001546037097157867, 'max_depth': 47, 'scale_pos_weight': 64}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:35:42,900] Trial 73 finished with value: 0.0 and parameters: {'num_leaves': 2338, 'n_estimators': 801, 'learning_rate': 0.0023259227764138067, 'max_depth': 25, 'scale_pos_weight': 71}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:35:43,643] Trial 74 finished with value: 0.0 and parameters: {'num_leaves': 653, 'n_estimators': 398, 'learning_rate': 0.004324995174343888, 'max_depth': 10, 'scale_pos_weight': 88}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:35:47,077] Trial 75 finished with value: 0.0 and parameters: {'num_leaves': 3096, 'n_estimators': 125, 'learning_rate': 0.00960423748748127, 'max_depth': 39, 'scale_pos_weight': 80}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:35:47,429] Trial 76 finished with value: 0.0 and parameters: {'num_leaves': 1182, 'n_estimators': 1903, 'learning_rate': 0.006053641813026195, 'max_depth': 5, 'scale_pos_weight': 96}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:35:52,645] Trial 77 finished with value: 0.0 and parameters: {'num_leaves': 1499, 'n_estimators': 1437, 'learning_rate': 0.005525227612534121, 'max_depth': 44, 'scale_pos_weight': 6}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:35:56,047] Trial 78 finished with value: 0.0 and parameters: {'num_leaves': 2960, 'n_estimators': 1187, 'learning_rate': 0.00921256769566003, 'max_depth': 32, 'scale_pos_weight': 10}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:35:58,443] Trial 79 finished with value: 0.0 and parameters: {'num_leaves': 2696, 'n_estimators': 617, 'learning_rate': 0.0065669062494546, 'max_depth': 20, 'scale_pos_weight': 64}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:36:02,915] Trial 80 finished with value: 0.0 and parameters: {'num_leaves': 2102, 'n_estimators': 2313, 'learning_rate': 0.0032940595254603326, 'max_depth': 29, 'scale_pos_weight': 30}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:36:09,772] Trial 81 finished with value: 0.0 and parameters: {'num_leaves': 3308, 'n_estimators': 977, 'learning_rate': 0.0015353574574255356, 'max_depth': 36, 'scale_pos_weight': 44}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:36:13,009] Trial 82 finished with value: 0.0 and parameters: {'num_leaves': 3678, 'n_estimators': 753, 'learning_rate': 0.009764524633600589, 'max_depth': 25, 'scale_pos_weight': 36}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:36:18,763] Trial 83 finished with value: 0.0 and parameters: {'num_leaves': 3357, 'n_estimators': 858, 'learning_rate': 0.0019461984876205155, 'max_depth': 33, 'scale_pos_weight': 50}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:36:22,310] Trial 84 finished with value: 0.0 and parameters: {'num_leaves': 3149, 'n_estimators': 2890, 'learning_rate': 0.008867817806119989, 'max_depth': 30, 'scale_pos_weight': 46}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:36:25,917] Trial 85 finished with value: 0.0 and parameters: {'num_leaves': 1053, 'n_estimators': 243, 'learning_rate': 0.005349857259296198, 'max_depth': 27, 'scale_pos_weight': 41}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:36:33,921] Trial 86 finished with value: 0.0 and parameters: {'num_leaves': 2431, 'n_estimators': 922, 'learning_rate': 0.0010416774321063125, 'max_depth': 46, 'scale_pos_weight': 52}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:36:39,738] Trial 87 finished with value: 0.0 and parameters: {'num_leaves': 3008, 'n_estimators': 451, 'learning_rate': 0.0094142190445241, 'max_depth': 41, 'scale_pos_weight': 3}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:36:41,806] Trial 88 finished with value: 0.0 and parameters: {'num_leaves': 402, 'n_estimators': 549, 'learning_rate': 0.00607755227033404, 'max_depth': 23, 'scale_pos_weight': 74}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:36:44,534] Trial 89 finished with value: 0.0 and parameters: {'num_leaves': 310, 'n_estimators': 189, 'learning_rate': 0.00810767039820626, 'max_depth': 37, 'scale_pos_weight': 20}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:36:47,578] Trial 90 finished with value: 0.0 and parameters: {'num_leaves': 1699, 'n_estimators': 1180, 'learning_rate': 0.004987414736666956, 'max_depth': 16, 'scale_pos_weight': 15}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:36:51,424] Trial 91 finished with value: 0.0 and parameters: {'num_leaves': 728, 'n_estimators': 1631, 'learning_rate': 0.005839692403308238, 'max_depth': 46, 'scale_pos_weight': 56}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:36:55,853] Trial 92 finished with value: 0.0 and parameters: {'num_leaves': 579, 'n_estimators': 1283, 'learning_rate': 0.002275161310954722, 'max_depth': 48, 'scale_pos_weight': 27}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:36:58,647] Trial 93 finished with value: 0.0 and parameters: {'num_leaves': 795, 'n_estimators': 1718, 'learning_rate': 0.007699032191638318, 'max_depth': 31, 'scale_pos_weight': 39}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:37:01,713] Trial 94 finished with value: 0.0 and parameters: {'num_leaves': 898, 'n_estimators': 1414, 'learning_rate': 0.0073334654466608125, 'max_depth': 50, 'scale_pos_weight': 33}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:37:05,820] Trial 95 finished with value: 0.0 and parameters: {'num_leaves': 2878, 'n_estimators': 701, 'learning_rate': 0.007031526466915519, 'max_depth': 45, 'scale_pos_weight': 28}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:37:08,662] Trial 96 finished with value: 0.0 and parameters: {'num_leaves': 982, 'n_estimators': 332, 'learning_rate': 0.009059123238319668, 'max_depth': 33, 'scale_pos_weight': 35}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:37:12,749] Trial 97 finished with value: 0.0 and parameters: {'num_leaves': 1257, 'n_estimators': 91, 'learning_rate': 0.006449352794542478, 'max_depth': 43, 'scale_pos_weight': 17}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:37:15,611] Trial 98 finished with value: 0.0 and parameters: {'num_leaves': 2235, 'n_estimators': 1088, 'learning_rate': 0.008371297963181368, 'max_depth': 28, 'scale_pos_weight': 100}. Best is trial 38 with value: 0.04915254237288136.
# [I 2024-05-25 09:37:19,300] Trial 99 finished with value: 0.0 and parameters: {'num_leaves': 2600, 'n_estimators': 2031, 'learning_rate': 0.008821025225923934, 'max_depth': 35, 'scale_pos_weight': 13}. Best is trial 38 with value: 0.04915254237288136.
# Best Parameters
# {'num_leaves': 2790, 'n_estimators': 975, 'learning_rate': 0.009582197489532705, 'max_depth': 26, 'scale_pos_weight': 3}
# Validation Score: 0.0000
# Uncalibrated ECE : 0.04432829077024138
# Calibrated ECE : 4.449812809436256e-16
# Uncalibrated ECE : 0.04432829077024138
# Calibrated ECE : 4.449812809436256e-16
# F1 Score: 0.0000
# ROC AUC Score: 0.5626
# Specificity Score: 1.0000
# Sensitivity Score: 0.0000
# Accuracy Score: 0.7588
# Precision Recall AUC Score: 0.2873
# PPV Score: nan
# NPV Score: 0.7588
# {'F1 Score': 0.0,
#  'ROC AUC Score': 0.5626492347438056,
#  'Specificity Score': 1.0,
#  'Sensitivity Score': 0.0,
#  'Accuracy Score': 0.7587616822429907,
#  'Precision Recall AUC Score': 0.28725567314784395,
#  'PPV Score': nan,
#  'NPV Score': 0.7587616822429907}

# %%
dice_d = X_test.iloc[:10].copy()

print(dice_d)
print(type(dice_d))
# Out:
#    Age at recruitment_x  Urea | Instance 0_x  Creatinine | Instance 0_x  \
# 0             -1.872432            -0.483296                  -0.577454
# 1              0.603786            -0.155854                  -0.050247
# 2             -1.212107             5.616649                  12.810969
# 3              0.768868             0.201745                   0.293439
# 4              0.933949             0.174805                  -0.075336
# 5              0.603786            -0.140775                  -0.500365
# 6              0.933949             7.117582                   5.122939
# 7              0.603786            -0.059956                   0.283022
# 8             -0.221620            -0.167488                   0.002636
# 9             -0.056539            -0.283171                   0.216351
#
#    Haemoglobin concentration | Instance 0  \
# 0                               -0.091121
# 1                                0.028736
# 2                               -0.020617
# 3                                0.656222
# 4                               -0.344936
# 5                                0.642121
# 6                               -0.993573
# 7                                0.902986
# 8                                0.413780
# 9                                2.291916
#
#    White blood cell (leukocyte) count | Instance 0_x  Albumin | Instance 0_x  \
# 0                                          -0.672635               -0.568439
# 1                                           1.382850                0.050007
# 2                                           3.003232               -0.022314
# 3                                           1.086530               -0.844755
# 4                                          -0.413824                0.122451
# 5                                           1.686672                0.096644
# 6                                           1.210309               -0.024442
# 7                                           0.531399                0.107321
# 8                                          -0.066976                0.051291
# 9                                          -0.702642                0.124985
#
#    Platelet count | Instance 0_x  Platelet distribution width | Instance 0  \
# 0                      -1.052870                                  1.268577
# 1                       1.288365                                  0.566916
# 2                       0.228773                                 -0.170727
# 3                      -0.474640                                 -0.134744
# 4                      -1.057341                                  1.718360
# 5                       0.303287                                 -1.070292
# 6                       0.280933                                 -1.358153
# 7                      -1.020084                                  0.566916
# 8                      -0.014924                                 -0.033741
# 9                      -0.313690                                  2.635916
#
#    Diastolic blood pressure_x  Diastolic blood pressure2_x  ...  \
# 0                    0.582594                     0.791701  ...
# 1                    0.251619                     0.706121  ...
# 2                   -1.237764                    -0.577578  ...
# 3                    0.097965                     0.089603  ...
# 4                   -0.906790                    -0.834318  ...
# 5                    0.334363                    -0.064098  ...
# 6                   -2.396174                    -2.545918  ...
# 7                    1.327286                     1.989821  ...
# 8                    1.575516                     1.390761  ...
# 9                    1.658260                     1.989821  ...
#
#    Body mass index (BMI) | Instance 0  Sex_x_encoded  \
# 0                           -0.289423       1.468614
# 1                           -0.378469      -0.680914
# 2                           -0.484629       1.468614
# 3                            2.280131      -0.680914
# 4                           -0.675486      -0.680914
# 5                            0.797593       1.468614
# 6                           -0.508623      -0.680914
# 7                           -1.413736      -0.680914
# 8                           -0.620213      -0.680914
# 9                           -0.235938      -0.680914
#
#    Ethnic background | Instance 0_encoded  \
# 0                                -0.26976
# 1                                -0.26976
# 2                                -0.26976
# 3                                -0.26976
# 4                                -0.26976
# 5                                -0.26976
# 6                                -0.26976
# 7                                -0.26976
# 8                                -0.26976
# 9                                -0.26976
#
#    Sleeplessness / insomnia | Instance 0_encoded  \
# 0                                       0.326838
# 1                                       1.638792
# 2                                       0.326838
# 3                                      -0.985115
# 4                                      -0.985115
# 5                                      -0.985115
# 6                                      -0.985115
# 7                                       0.326838
# 8                                       1.638792
# 9                                       1.638792
#
#    Smoking status | Instance 0_x_encoded  \
# 0                               0.104856
# 1                              -0.979185
# 2                               1.188897
# 3                              -0.979185
# 4                               1.188897
# 5                               0.104856
# 6                               0.104856
# 7                              -0.979185
# 8                              -0.979185
# 9                              -0.979185
#
#    Processed meat intake | Instance 0_encoded  \
# 0                                   -0.244569
# 1                                   -1.021287
# 2                                    0.532149
# 3                                    0.532149
# 4                                   -1.021287
# 5                                   -1.021287
# 6                                   -1.021287
# 7                                    0.532149
# 8                                   -0.244569
# 9                                   -1.021287
#
#    Coffee intake | Instance 0_encoded  \
# 0                            1.358703
# 1                            3.573269
# 2                            0.620514
# 3                           -1.224957
# 4                           -1.224957
# 5                           -1.224957
# 6                           -0.486769
# 7                           -1.224957
# 8                           -0.486769
# 9                           -1.224957
#
#    Alcohol drinker status | Instance 0_x_encoded  \
# 0                                       2.977353
# 1                                      -0.382971
# 2                                       1.297191
# 3                                      -0.382971
# 4                                      -0.382971
# 5                                      -0.382971
# 6                                      -0.382971
# 7                                      -0.382971
# 8                                      -0.382971
# 9                                      -0.382971
#
#    Alcohol intake frequency. | Instance 0_encoded  \
# 0                                        1.417475
# 1                                        0.278970
# 2                                        1.417475
# 3                                        0.278970
# 4                                        0.848222
# 5                                        0.278970
# 6                                        0.848222
# 7                                       -1.428786
# 8                                       -1.428786
# 9                                       -1.428786
#
#    Pace-maker | Instance 0_encoded
# 0                        -0.176964
# 1                        -0.176964
# 2                        -0.176964
# 3                        -0.176964
# 4                        -0.176964
# 5                        -0.176964
# 6                        -0.176964
# 7                        -0.176964
# 8                        -0.176964
# 9                        -0.176964
#
# [10 rows x 60 columns]
# <class 'pandas.core.frame.DataFrame'>

# %%
dice = rias.get_counterfactual_explanations(dice_d, features_to_vary=["Cholesterol | Instance 0", "Weight | Instance 0"])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [01:38<00:00,  9.87s/it]
# Query instance (original outcome : 0)
#    Age at recruitment_x  Urea | Instance 0_x  Creatinine | Instance 0_x  \
# 0             -1.872432            -0.483296                  -0.577454
#
#    Haemoglobin concentration | Instance 0  \
# 0                               -0.091121
#
#    White blood cell (leukocyte) count | Instance 0_x  Albumin | Instance 0_x  \
# 0                                          -0.672635               -0.568439
#
#    Platelet count | Instance 0_x  Platelet distribution width | Instance 0  \
# 0                       -1.05287                                  1.268577
#
#    Diastolic blood pressure_x  Diastolic blood pressure2_x  ...  \
# 0                    0.582594                     0.791701  ...
#
#         Sex_x_encoded  Ethnic background | Instance 0_encoded  \
# 0  1.4686138254373244                      -0.269760297135527
#
#    Sleeplessness / insomnia | Instance 0_encoded  \
# 0                            0.32683821434180793
#
#    Smoking status | Instance 0_x_encoded  \
# 0                     0.1048560631458576
#
#    Processed meat intake | Instance 0_encoded  \
# 0                        -0.24456856308405314
#
#    Coffee intake | Instance 0_encoded  \
# 0                   1.358702896433432
#
#    Alcohol drinker status | Instance 0_x_encoded  \
# 0                              2.977353463491117
#
#    Alcohol intake frequency. | Instance 0_encoded  \
# 0                              1.4174745449852848
#
#    Pace-maker | Instance 0_encoded  target
# 0             -0.17696396228338865       0
#
# [1 rows x 61 columns]
# Diverse Counterfactual set (new outcome: 0)
#    Age at recruitment_x  Urea | Instance 0_x  Creatinine | Instance 0_x  \
# 0             -1.872432            -0.483296                  -0.577454
# 1             -1.872432            -0.483296                  -0.577454
# 2             -1.872432            -0.483296                  -0.577454
# 3             -1.872432            -0.483296                  -0.577454
#
#    Haemoglobin concentration | Instance 0  \
# 0                               -0.091121
# 1                               -0.091121
# 2                               -0.091121
# 3                               -0.091121
#
#    White blood cell (leukocyte) count | Instance 0_x  Albumin | Instance 0_x  \
# 0                                          -0.672635               -0.568439
# 1                                          -0.672635               -0.568439
# 2                                          -0.672635               -0.568439
# 3                                          -0.672635               -0.568439
#
#    Platelet count | Instance 0_x  Platelet distribution width | Instance 0  \
# 0                       -1.05287                                  1.268577
# 1                       -1.05287                                  1.268577
# 2                       -1.05287                                  1.268577
# 3                       -1.05287                                  1.268577
#
#    Diastolic blood pressure_x  Diastolic blood pressure2_x  ...  \
# 0                    0.582594                     0.791701  ...
# 1                    0.582594                     0.791701  ...
# 2                    0.582594                     0.791701  ...
# 3                    0.582594                     0.791701  ...
#
#    Sex_x_encoded  Ethnic background | Instance 0_encoded  \
# 0       1.468614                                -0.26976
# 1       1.468614                                -0.26976
# 2       1.468614                                -0.26976
# 3       1.468614                                -0.26976
#
#    Sleeplessness / insomnia | Instance 0_encoded  \
# 0                                       0.326838
# 1                                       0.326838
# 2                                       0.326838
# 3                                       0.326838
#
#    Smoking status | Instance 0_x_encoded  \
# 0                               0.104856
# 1                               0.104856
# 2                               0.104856
# 3                               0.104856
#
#    Processed meat intake | Instance 0_encoded  \
# 0                                   -0.244569
# 1                                   -0.244569
# 2                                   -0.244569
# 3                                   -0.244569
#
#    Coffee intake | Instance 0_encoded  \
# 0                            1.358703
# 1                            1.358703
# 2                            1.358703
# 3                            1.358703
#
#    Alcohol drinker status | Instance 0_x_encoded  \
# 0                                       2.977353
# 1                                       2.977353
# 2                                       2.977353
# 3                                       2.977353
#
#    Alcohol intake frequency. | Instance 0_encoded  \
# 0                                        1.417475
# 1                                        1.417475
# 2                                        1.417475
# 3                                        1.417475
#
#    Pace-maker | Instance 0_encoded  target
# 0                        -0.176964       0
# 1                        -0.176964       0
# 2                        -0.176964       0
# 3                        -0.176964       0
#
# [4 rows x 61 columns]
# Query instance (original outcome : 0)
#    Age at recruitment_x  Urea | Instance 0_x  Creatinine | Instance 0_x  \
# 0              0.603786            -0.155854                  -0.050247
#
#    Haemoglobin concentration | Instance 0  \
# 0                                0.028736
#
#    White blood cell (leukocyte) count | Instance 0_x  Albumin | Instance 0_x  \
# 0                                            1.38285                0.050007
#
#    Platelet count | Instance 0_x  Platelet distribution width | Instance 0  \
# 0                       1.288365                                  0.566916
#
#    Diastolic blood pressure_x  Diastolic blood pressure2_x  ...  \
# 0                    0.251619                     0.706121  ...
#
#        Sex_x_encoded  Ethnic background | Instance 0_encoded  \
# 0  -0.68091419451414                      -0.269760297135527
#
#    Sleeplessness / insomnia | Instance 0_encoded  \
# 0                             1.6387917269255816
#
#    Smoking status | Instance 0_x_encoded  \
# 0                    -0.9791845655101079
#
#    Processed meat intake | Instance 0_encoded  \
# 0                          -1.021286542549139
#
#    Coffee intake | Instance 0_encoded  \
# 0                   3.573268893859107
#
#    Alcohol drinker status | Instance 0_x_encoded  \
# 0                           -0.38297092703216873
#
#    Alcohol intake frequency. | Instance 0_encoded  \
# 0                              0.2789701692219603
#
#    Pace-maker | Instance 0_encoded  target
# 0             -0.17696396228338865       0
#
# [1 rows x 61 columns]
# Diverse Counterfactual set (new outcome: 0)
#    Age at recruitment_x  Urea | Instance 0_x  Creatinine | Instance 0_x  \
# 0              0.603786            -0.155854                  -0.050247
# 1              0.603786            -0.155854                  -0.050247
# 2              0.603786            -0.155854                  -0.050247
# 3              0.603786            -0.155854                  -0.050247
#
#    Haemoglobin concentration | Instance 0  \
# 0                                0.028736
# 1                                0.028736
# 2                                0.028736
# 3                                0.028736
#
#    White blood cell (leukocyte) count | Instance 0_x  Albumin | Instance 0_x  \
# 0                                            1.38285                0.050007
# 1                                            1.38285                0.050007
# 2                                            1.38285                0.050007
# 3                                            1.38285                0.050007
#
#    Platelet count | Instance 0_x  Platelet distribution width | Instance 0  \
# 0                       1.288365                                  0.566916
# 1                       1.288365                                  0.566916
# 2                       1.288365                                  0.566916
# 3                       1.288365                                  0.566916
#
#    Diastolic blood pressure_x  Diastolic blood pressure2_x  ...  \
# 0                    0.251619                     0.706121  ...
# 1                    0.251619                     0.706121  ...
# 2                    0.251619                     0.706121  ...
# 3                    0.251619                     0.706121  ...
#
#    Sex_x_encoded  Ethnic background | Instance 0_encoded  \
# 0      -0.680914                                -0.26976
# 1      -0.680914                                -0.26976
# 2      -0.680914                                -0.26976
# 3      -0.680914                                -0.26976
#
#    Sleeplessness / insomnia | Instance 0_encoded  \
# 0                                       1.638792
# 1                                       1.638792
# 2                                       1.638792
# 3                                       1.638792
#
#    Smoking status | Instance 0_x_encoded  \
# 0                              -0.979185
# 1                              -0.979185
# 2                              -0.979185
# 3                              -0.979185
#
#    Processed meat intake | Instance 0_encoded  \
# 0                                   -1.021287
# 1                                   -1.021287
# 2                                   -1.021287
# 3                                   -1.021287
#
#    Coffee intake | Instance 0_encoded  \
# 0                            3.573269
# 1                            3.573269
# 2                            3.573269
# 3                            3.573269
#
#    Alcohol drinker status | Instance 0_x_encoded  \
# 0                                      -0.382971
# 1                                      -0.382971
# 2                                      -0.382971
# 3                                      -0.382971
#
#    Alcohol intake frequency. | Instance 0_encoded  \
# 0                                         0.27897
# 1                                         0.27897
# 2                                         0.27897
# 3                                         0.27897
#
#    Pace-maker | Instance 0_encoded  target
# 0                        -0.176964       0
# 1                        -0.176964       0
# 2                        -0.176964       0
# 3                        -0.176964       0
#
# [4 rows x 61 columns]
# Query instance (original outcome : 0)
#    Age at recruitment_x  Urea | Instance 0_x  Creatinine | Instance 0_x  \
# 0             -1.212107             5.616649                  12.810969
#
#    Haemoglobin concentration | Instance 0  \
# 0                               -0.020617
#
#    White blood cell (leukocyte) count | Instance 0_x  Albumin | Instance 0_x  \
# 0                                           3.003232               -0.022314
#
#    Platelet count | Instance 0_x  Platelet distribution width | Instance 0  \
# 0                       0.228773                                 -0.170727
#
#    Diastolic blood pressure_x  Diastolic blood pressure2_x  ...  \
# 0                   -1.237764                    -0.577578  ...
#
#         Sex_x_encoded  Ethnic background | Instance 0_encoded  \
# 0  1.4686138254373244                      -0.269760297135527
#
#    Sleeplessness / insomnia | Instance 0_encoded  \
# 0                            0.32683821434180793
#
#    Smoking status | Instance 0_x_encoded  \
# 0                     1.1888966918018231
#
#    Processed meat intake | Instance 0_encoded  \
# 0                          0.5321494163810329
#
#    Coffee intake | Instance 0_encoded  \
# 0                  0.6205142306248738
#
#    Alcohol drinker status | Instance 0_x_encoded  \
# 0                              1.297191268229474
#
#    Alcohol intake frequency. | Instance 0_encoded  \
# 0                              1.4174745449852848
#
#    Pace-maker | Instance 0_encoded  target
# 0             -0.17696396228338865       0
#
# [1 rows x 61 columns]
# Diverse Counterfactual set (new outcome: 0)
#    Age at recruitment_x  Urea | Instance 0_x  Creatinine | Instance 0_x  \
# 0             -1.212107             5.616649                  12.810969
# 1             -1.212107             5.616649                  12.810969
# 2             -1.212107             5.616649                  12.810969
# 3             -1.212107             5.616649                  12.810969
#
#    Haemoglobin concentration | Instance 0  \
# 0                               -0.020617
# 1                               -0.020617
# 2                               -0.020617
# 3                               -0.020617
#
#    White blood cell (leukocyte) count | Instance 0_x  Albumin | Instance 0_x  \
# 0                                           3.003232               -0.022314
# 1                                           3.003232               -0.022314
# 2                                           3.003232               -0.022314
# 3                                           3.003232               -0.022314
#
#    Platelet count | Instance 0_x  Platelet distribution width | Instance 0  \
# 0                       0.228773                                 -0.170727
# 1                       0.228773                                 -0.170727
# 2                       0.228773                                 -0.170727
# 3                       0.228773                                 -0.170727
#
#    Diastolic blood pressure_x  Diastolic blood pressure2_x  ...  \
# 0                   -1.237764                    -0.577578  ...
# 1                   -1.237764                    -0.577578  ...
# 2                   -1.237764                    -0.577578  ...
# 3                   -1.237764                    -0.577578  ...
#
#    Sex_x_encoded  Ethnic background | Instance 0_encoded  \
# 0       1.468614                                -0.26976
# 1       1.468614                                -0.26976
# 2       1.468614                                -0.26976
# 3       1.468614                                -0.26976
#
#    Sleeplessness / insomnia | Instance 0_encoded  \
# 0                                       0.326838
# 1                                       0.326838
# 2                                       0.326838
# 3                                       0.326838
#
#    Smoking status | Instance 0_x_encoded  \
# 0                               1.188897
# 1                               1.188897
# 2                               1.188897
# 3                               1.188897
#
#    Processed meat intake | Instance 0_encoded  \
# 0                                    0.532149
# 1                                    0.532149
# 2                                    0.532149
# 3                                    0.532149
#
#    Coffee intake | Instance 0_encoded  \
# 0                            0.620514
# 1                            0.620514
# 2                            0.620514
# 3                            0.620514
#
#    Alcohol drinker status | Instance 0_x_encoded  \
# 0                                       1.297191
# 1                                       1.297191
# 2                                       1.297191
# 3                                       1.297191
#
#    Alcohol intake frequency. | Instance 0_encoded  \
# 0                                        1.417475
# 1                                        1.417475
# 2                                        1.417475
# 3                                        1.417475
#
#    Pace-maker | Instance 0_encoded  target
# 0                        -0.176964       0
# 1                        -0.176964       0
# 2                        -0.176964       0
# 3                        -0.176964       0
#
# [4 rows x 61 columns]
# Query instance (original outcome : 0)
#    Age at recruitment_x  Urea | Instance 0_x  Creatinine | Instance 0_x  \
# 0              0.768868             0.201745                   0.293439
#
#    Haemoglobin concentration | Instance 0  \
# 0                                0.656222
#
#    White blood cell (leukocyte) count | Instance 0_x  Albumin | Instance 0_x  \
# 0                                            1.08653               -0.844755
#
#    Platelet count | Instance 0_x  Platelet distribution width | Instance 0  \
# 0                       -0.47464                                 -0.134744
#
#    Diastolic blood pressure_x  Diastolic blood pressure2_x  ...  \
# 0                    0.097965                     0.089603  ...
#
#        Sex_x_encoded  Ethnic background | Instance 0_encoded  \
# 0  -0.68091419451414                      -0.269760297135527
#
#    Sleeplessness / insomnia | Instance 0_encoded  \
# 0                            -0.9851152982419655
#
#    Smoking status | Instance 0_x_encoded  \
# 0                    -0.9791845655101079
#
#    Processed meat intake | Instance 0_encoded  \
# 0                          0.5321494163810329
#
#    Coffee intake | Instance 0_encoded  \
# 0                  -1.224957433896522
#
#    Alcohol drinker status | Instance 0_x_encoded  \
# 0                           -0.38297092703216873
#
#    Alcohol intake frequency. | Instance 0_encoded  \
# 0                              0.2789701692219603
#
#    Pace-maker | Instance 0_encoded  target
# 0             -0.17696396228338865       0
#
# [1 rows x 61 columns]
# Diverse Counterfactual set (new outcome: 0)
#    Age at recruitment_x  Urea | Instance 0_x  Creatinine | Instance 0_x  \
# 0              0.768868             0.201745                   0.293439
# 1              0.768868             0.201745                   0.293439
# 2              0.768868             0.201745                   0.293439
# 3              0.768868             0.201745                   0.293439
#
#    Haemoglobin concentration | Instance 0  \
# 0                                0.656222
# 1                                0.656222
# 2                                0.656222
# 3                                0.656222
#
#    White blood cell (leukocyte) count | Instance 0_x  Albumin | Instance 0_x  \
# 0                                            1.08653               -0.844755
# 1                                            1.08653               -0.844755
# 2                                            1.08653               -0.844755
# 3                                            1.08653               -0.844755
#
#    Platelet count | Instance 0_x  Platelet distribution width | Instance 0  \
# 0                       -0.47464                                 -0.134744
# 1                       -0.47464                                 -0.134744
# 2                       -0.47464                                 -0.134744
# 3                       -0.47464                                 -0.134744
#
#    Diastolic blood pressure_x  Diastolic blood pressure2_x  ...  \
# 0                    0.097965                     0.089603  ...
# 1                    0.097965                     0.089603  ...
# 2                    0.097965                     0.089603  ...
# 3                    0.097965                     0.089603  ...
#
#    Sex_x_encoded  Ethnic background | Instance 0_encoded  \
# 0      -0.680914                                -0.26976
# 1      -0.680914                                -0.26976
# 2      -0.680914                                -0.26976
# 3      -0.680914                                -0.26976
#
#    Sleeplessness / insomnia | Instance 0_encoded  \
# 0                                      -0.985115
# 1                                      -0.985115
# 2                                      -0.985115
# 3                                      -0.985115
#
#    Smoking status | Instance 0_x_encoded  \
# 0                              -0.979185
# 1                              -0.979185
# 2                              -0.979185
# 3                              -0.979185
#
#    Processed meat intake | Instance 0_encoded  \
# 0                                    0.532149
# 1                                    0.532149
# 2                                    0.532149
# 3                                    0.532149
#
#    Coffee intake | Instance 0_encoded  \
# 0                           -1.224957
# 1                           -1.224957
# 2                           -1.224957
# 3                           -1.224957
#
#    Alcohol drinker status | Instance 0_x_encoded  \
# 0                                      -0.382971
# 1                                      -0.382971
# 2                                      -0.382971
# 3                                      -0.382971
#
#    Alcohol intake frequency. | Instance 0_encoded  \
# 0                                         0.27897
# 1                                         0.27897
# 2                                         0.27897
# 3                                         0.27897
#
#    Pace-maker | Instance 0_encoded  target
# 0                        -0.176964       0
# 1                        -0.176964       0
# 2                        -0.176964       0
# 3                        -0.176964       0
#
# [4 rows x 61 columns]
# Query instance (original outcome : 0)
#    Age at recruitment_x  Urea | Instance 0_x  Creatinine | Instance 0_x  \
# 0              0.933949             0.174805                  -0.075336
#
#    Haemoglobin concentration | Instance 0  \
# 0                               -0.344936
#
#    White blood cell (leukocyte) count | Instance 0_x  Albumin | Instance 0_x  \
# 0                                          -0.413824                0.122451
#
#    Platelet count | Instance 0_x  Platelet distribution width | Instance 0  \
# 0                      -1.057341                                   1.71836
#
#    Diastolic blood pressure_x  Diastolic blood pressure2_x  ...  \
# 0                    -0.90679                    -0.834318  ...
#
#        Sex_x_encoded  Ethnic background | Instance 0_encoded  \
# 0  -0.68091419451414                      -0.269760297135527
#
#    Sleeplessness / insomnia | Instance 0_encoded  \
# 0                            -0.9851152982419655
#
#    Smoking status | Instance 0_x_encoded  \
# 0                     1.1888966918018231
#
#    Processed meat intake | Instance 0_encoded  \
# 0                          -1.021286542549139
#
#    Coffee intake | Instance 0_encoded  \
# 0                  -1.224957433896522
#
#    Alcohol drinker status | Instance 0_x_encoded  \
# 0                           -0.38297092703216873
#
#    Alcohol intake frequency. | Instance 0_encoded  \
# 0                              0.8482223571036226
#
#    Pace-maker | Instance 0_encoded  target
# 0             -0.17696396228338865       0
#
# [1 rows x 61 columns]
# Diverse Counterfactual set (new outcome: 0)
#    Age at recruitment_x  Urea | Instance 0_x  Creatinine | Instance 0_x  \
# 0              0.933949             0.174805                  -0.075336
# 1              0.933949             0.174805                  -0.075336
# 2              0.933949             0.174805                  -0.075336
# 3              0.933949             0.174805                  -0.075336
#
#    Haemoglobin concentration | Instance 0  \
# 0                               -0.344936
# 1                               -0.344936
# 2                               -0.344936
# 3                               -0.344936
#
#    White blood cell (leukocyte) count | Instance 0_x  Albumin | Instance 0_x  \
# 0                                          -0.413824                0.122451
# 1                                          -0.413824                0.122451
# 2                                          -0.413824                0.122451
# 3                                          -0.413824                0.122451
#
#    Platelet count | Instance 0_x  Platelet distribution width | Instance 0  \
# 0                      -1.057341                                   1.71836
# 1                      -1.057341                                   1.71836
# 2                      -1.057341                                   1.71836
# 3                      -1.057341                                   1.71836
#
#    Diastolic blood pressure_x  Diastolic blood pressure2_x  ...  \
# 0                    -0.90679                    -0.834318  ...
# 1                    -0.90679                    -0.834318  ...
# 2                    -0.90679                    -0.834318  ...
# 3                    -0.90679                    -0.834318  ...
#
#    Sex_x_encoded  Ethnic background | Instance 0_encoded  \
# 0      -0.680914                                -0.26976
# 1      -0.680914                                -0.26976
# 2      -0.680914                                -0.26976
# 3      -0.680914                                -0.26976
#
#    Sleeplessness / insomnia | Instance 0_encoded  \
# 0                                      -0.985115
# 1                                      -0.985115
# 2                                      -0.985115
# 3                                      -0.985115
#
#    Smoking status | Instance 0_x_encoded  \
# 0                               1.188897
# 1                               1.188897
# 2                               1.188897
# 3                               1.188897
#
#    Processed meat intake | Instance 0_encoded  \
# 0                                   -1.021287
# 1                                   -1.021287
# 2                                   -1.021287
# 3                                   -1.021287
#
#    Coffee intake | Instance 0_encoded  \
# 0                           -1.224957
# 1                           -1.224957
# 2                           -1.224957
# 3                           -1.224957
#
#    Alcohol drinker status | Instance 0_x_encoded  \
# 0                                      -0.382971
# 1                                      -0.382971
# 2                                      -0.382971
# 3                                      -0.382971
#
#    Alcohol intake frequency. | Instance 0_encoded  \
# 0                                        0.848222
# 1                                        0.848222
# 2                                        0.848222
# 3                                        0.848222
#
#    Pace-maker | Instance 0_encoded  target
# 0                        -0.176964       0
# 1                        -0.176964       0
# 2                        -0.176964       0
# 3                        -0.176964       0
#
# [4 rows x 61 columns]
# Query instance (original outcome : 0)
#    Age at recruitment_x  Urea | Instance 0_x  Creatinine | Instance 0_x  \
# 0              0.603786            -0.140775                  -0.500365
#
#    Haemoglobin concentration | Instance 0  \
# 0                                0.642121
#
#    White blood cell (leukocyte) count | Instance 0_x  Albumin | Instance 0_x  \
# 0                                           1.686672                0.096644
#
#    Platelet count | Instance 0_x  Platelet distribution width | Instance 0  \
# 0                       0.303288                                 -1.070292
#
#    Diastolic blood pressure_x  Diastolic blood pressure2_x  ...  \
# 0                    0.334363                    -0.064098  ...
#
#         Sex_x_encoded  Ethnic background | Instance 0_encoded  \
# 0  1.4686138254373244                      -0.269760297135527
#
#    Sleeplessness / insomnia | Instance 0_encoded  \
# 0                            -0.9851152982419655
#
#    Smoking status | Instance 0_x_encoded  \
# 0                     0.1048560631458576
#
#    Processed meat intake | Instance 0_encoded  \
# 0                          -1.021286542549139
#
#    Coffee intake | Instance 0_encoded  \
# 0                  -1.224957433896522
#
#    Alcohol drinker status | Instance 0_x_encoded  \
# 0                           -0.38297092703216873
#
#    Alcohol intake frequency. | Instance 0_encoded  \
# 0                              0.2789701692219603
#
#    Pace-maker | Instance 0_encoded  target
# 0             -0.17696396228338865       0
#
# [1 rows x 61 columns]
# Diverse Counterfactual set (new outcome: 0)
#    Age at recruitment_x  Urea | Instance 0_x  Creatinine | Instance 0_x  \
# 0              0.603786            -0.140775                  -0.500365
# 1              0.603786            -0.140775                  -0.500365
# 2              0.603786            -0.140775                  -0.500365
# 3              0.603786            -0.140775                  -0.500365
#
#    Haemoglobin concentration | Instance 0  \
# 0                                0.642121
# 1                                0.642121
# 2                                0.642121
# 3                                0.642121
#
#    White blood cell (leukocyte) count | Instance 0_x  Albumin | Instance 0_x  \
# 0                                           1.686672                0.096644
# 1                                           1.686672                0.096644
# 2                                           1.686672                0.096644
# 3                                           1.686672                0.096644
#
#    Platelet count | Instance 0_x  Platelet distribution width | Instance 0  \
# 0                       0.303287                                 -1.070292
# 1                       0.303287                                 -1.070292
# 2                       0.303287                                 -1.070292
# 3                       0.303287                                 -1.070292
#
#    Diastolic blood pressure_x  Diastolic blood pressure2_x  ...  \
# 0                    0.334363                    -0.064098  ...
# 1                    0.334363                    -0.064098  ...
# 2                    0.334363                    -0.064098  ...
# 3                    0.334363                    -0.064098  ...
#
#    Sex_x_encoded  Ethnic background | Instance 0_encoded  \
# 0       1.468614                                -0.26976
# 1       1.468614                                -0.26976
# 2       1.468614                                -0.26976
# 3       1.468614                                -0.26976
#
#    Sleeplessness / insomnia | Instance 0_encoded  \
# 0                                      -0.985115
# 1                                      -0.985115
# 2                                      -0.985115
# 3                                      -0.985115
#
#    Smoking status | Instance 0_x_encoded  \
# 0                               0.104856
# 1                               0.104856
# 2                               0.104856
# 3                               0.104856
#
#    Processed meat intake | Instance 0_encoded  \
# 0                                   -1.021287
# 1                                   -1.021287
# 2                                   -1.021287
# 3                                   -1.021287
#
#    Coffee intake | Instance 0_encoded  \
# 0                           -1.224957
# 1                           -1.224957
# 2                           -1.224957
# 3                           -1.224957
#
#    Alcohol drinker status | Instance 0_x_encoded  \
# 0                                      -0.382971
# 1                                      -0.382971
# 2                                      -0.382971
# 3                                      -0.382971
#
#    Alcohol intake frequency. | Instance 0_encoded  \
# 0                                         0.27897
# 1                                         0.27897
# 2                                         0.27897
# 3                                         0.27897
#
#    Pace-maker | Instance 0_encoded  target
# 0                        -0.176964       0
# 1                        -0.176964       0
# 2                        -0.176964       0
# 3                        -0.176964       0
#
# [4 rows x 61 columns]
# Query instance (original outcome : 0)
#    Age at recruitment_x  Urea | Instance 0_x  Creatinine | Instance 0_x  \
# 0              0.933949             7.117582                   5.122939
#
#    Haemoglobin concentration | Instance 0  \
# 0                               -0.993573
#
#    White blood cell (leukocyte) count | Instance 0_x  Albumin | Instance 0_x  \
# 0                                           1.210309               -0.024442
#
#    Platelet count | Instance 0_x  Platelet distribution width | Instance 0  \
# 0                       0.280933                                 -1.358153
#
#    Diastolic blood pressure_x  Diastolic blood pressure2_x  ...  \
# 0                   -2.396174                    -2.545918  ...
#
#        Sex_x_encoded  Ethnic background | Instance 0_encoded  \
# 0  -0.68091419451414                      -0.269760297135527
#
#    Sleeplessness / insomnia | Instance 0_encoded  \
# 0                            -0.9851152982419655
#
#    Smoking status | Instance 0_x_encoded  \
# 0                     0.1048560631458576
#
#    Processed meat intake | Instance 0_encoded  \
# 0                          -1.021286542549139
#
#    Coffee intake | Instance 0_encoded  \
# 0                -0.48676876808796365
#
#    Alcohol drinker status | Instance 0_x_encoded  \
# 0                           -0.38297092703216873
#
#    Alcohol intake frequency. | Instance 0_encoded  \
# 0                              0.8482223571036226
#
#    Pace-maker | Instance 0_encoded  target
# 0             -0.17696396228338865       0
#
# [1 rows x 61 columns]
# Diverse Counterfactual set (new outcome: 0)
#    Age at recruitment_x  Urea | Instance 0_x  Creatinine | Instance 0_x  \
# 0              0.933949             7.117582                   5.122939
# 1              0.933949             7.117582                   5.122939
# 2              0.933949             7.117582                   5.122939
# 3              0.933949             7.117582                   5.122939
#
#    Haemoglobin concentration | Instance 0  \
# 0                               -0.993573
# 1                               -0.993573
# 2                               -0.993573
# 3                               -0.993573
#
#    White blood cell (leukocyte) count | Instance 0_x  Albumin | Instance 0_x  \
# 0                                           1.210309               -0.024442
# 1                                           1.210309               -0.024442
# 2                                           1.210309               -0.024442
# 3                                           1.210309               -0.024442
#
#    Platelet count | Instance 0_x  Platelet distribution width | Instance 0  \
# 0                       0.280933                                 -1.358153
# 1                       0.280933                                 -1.358153
# 2                       0.280933                                 -1.358153
# 3                       0.280933                                 -1.358153
#
#    Diastolic blood pressure_x  Diastolic blood pressure2_x  ...  \
# 0                   -2.396174                    -2.545918  ...
# 1                   -2.396174                    -2.545918  ...
# 2                   -2.396174                    -2.545918  ...
# 3                   -2.396174                    -2.545918  ...
#
#    Sex_x_encoded  Ethnic background | Instance 0_encoded  \
# 0      -0.680914                                -0.26976
# 1      -0.680914                                -0.26976
# 2      -0.680914                                -0.26976
# 3      -0.680914                                -0.26976
#
#    Sleeplessness / insomnia | Instance 0_encoded  \
# 0                                      -0.985115
# 1                                      -0.985115
# 2                                      -0.985115
# 3                                      -0.985115
#
#    Smoking status | Instance 0_x_encoded  \
# 0                               0.104856
# 1                               0.104856
# 2                               0.104856
# 3                               0.104856
#
#    Processed meat intake | Instance 0_encoded  \
# 0                                   -1.021287
# 1                                   -1.021287
# 2                                   -1.021287
# 3                                   -1.021287
#
#    Coffee intake | Instance 0_encoded  \
# 0                           -0.486769
# 1                           -0.486769
# 2                           -0.486769
# 3                           -0.486769
#
#    Alcohol drinker status | Instance 0_x_encoded  \
# 0                                      -0.382971
# 1                                      -0.382971
# 2                                      -0.382971
# 3                                      -0.382971
#
#    Alcohol intake frequency. | Instance 0_encoded  \
# 0                                        0.848222
# 1                                        0.848222
# 2                                        0.848222
# 3                                        0.848222
#
#    Pace-maker | Instance 0_encoded  target
# 0                        -0.176964       0
# 1                        -0.176964       0
# 2                        -0.176964       0
# 3                        -0.176964       0
#
# [4 rows x 61 columns]
# Query instance (original outcome : 0)
#    Age at recruitment_x  Urea | Instance 0_x  Creatinine | Instance 0_x  \
# 0              0.603786            -0.059956                   0.283022
#
#    Haemoglobin concentration | Instance 0  \
# 0                                0.902986
#
#    White blood cell (leukocyte) count | Instance 0_x  Albumin | Instance 0_x  \
# 0                                           0.531399                0.107321
#
#    Platelet count | Instance 0_x  Platelet distribution width | Instance 0  \
# 0                      -1.020084                                  0.566916
#
#    Diastolic blood pressure_x  Diastolic blood pressure2_x  ...  \
# 0                    1.327286                     1.989821  ...
#
#        Sex_x_encoded  Ethnic background | Instance 0_encoded  \
# 0  -0.68091419451414                      -0.269760297135527
#
#    Sleeplessness / insomnia | Instance 0_encoded  \
# 0                            0.32683821434180793
#
#    Smoking status | Instance 0_x_encoded  \
# 0                    -0.9791845655101079
#
#    Processed meat intake | Instance 0_encoded  \
# 0                          0.5321494163810329
#
#    Coffee intake | Instance 0_encoded  \
# 0                  -1.224957433896522
#
#    Alcohol drinker status | Instance 0_x_encoded  \
# 0                           -0.38297092703216873
#
#    Alcohol intake frequency. | Instance 0_encoded  \
# 0                             -1.4287863944230266
#
#    Pace-maker | Instance 0_encoded  target
# 0             -0.17696396228338865       0
#
# [1 rows x 61 columns]
# Diverse Counterfactual set (new outcome: 0)
#    Age at recruitment_x  Urea | Instance 0_x  Creatinine | Instance 0_x  \
# 0              0.603786            -0.059956                   0.283022
# 1              0.603786            -0.059956                   0.283022
# 2              0.603786            -0.059956                   0.283022
# 3              0.603786            -0.059956                   0.283022
#
#    Haemoglobin concentration | Instance 0  \
# 0                                0.902986
# 1                                0.902986
# 2                                0.902986
# 3                                0.902986
#
#    White blood cell (leukocyte) count | Instance 0_x  Albumin | Instance 0_x  \
# 0                                           0.531399                0.107321
# 1                                           0.531399                0.107321
# 2                                           0.531399                0.107321
# 3                                           0.531399                0.107321
#
#    Platelet count | Instance 0_x  Platelet distribution width | Instance 0  \
# 0                      -1.020084                                  0.566916
# 1                      -1.020084                                  0.566916
# 2                      -1.020084                                  0.566916
# 3                      -1.020084                                  0.566916
#
#    Diastolic blood pressure_x  Diastolic blood pressure2_x  ...  \
# 0                    1.327286                     1.989821  ...
# 1                    1.327286                     1.989821  ...
# 2                    1.327286                     1.989821  ...
# 3                    1.327286                     1.989821  ...
#
#    Sex_x_encoded  Ethnic background | Instance 0_encoded  \
# 0      -0.680914                                -0.26976
# 1      -0.680914                                -0.26976
# 2      -0.680914                                -0.26976
# 3      -0.680914                                -0.26976
#
#    Sleeplessness / insomnia | Instance 0_encoded  \
# 0                                       0.326838
# 1                                       0.326838
# 2                                       0.326838
# 3                                       0.326838
#
#    Smoking status | Instance 0_x_encoded  \
# 0                              -0.979185
# 1                              -0.979185
# 2                              -0.979185
# 3                              -0.979185
#
#    Processed meat intake | Instance 0_encoded  \
# 0                                    0.532149
# 1                                    0.532149
# 2                                    0.532149
# 3                                    0.532149
#
#    Coffee intake | Instance 0_encoded  \
# 0                           -1.224957
# 1                           -1.224957
# 2                           -1.224957
# 3                           -1.224957
#
#    Alcohol drinker status | Instance 0_x_encoded  \
# 0                                      -0.382971
# 1                                      -0.382971
# 2                                      -0.382971
# 3                                      -0.382971
#
#    Alcohol intake frequency. | Instance 0_encoded  \
# 0                                       -1.428786
# 1                                       -1.428786
# 2                                       -1.428786
# 3                                       -1.428786
#
#    Pace-maker | Instance 0_encoded  target
# 0                        -0.176964       0
# 1                        -0.176964       0
# 2                        -0.176964       0
# 3                        -0.176964       0
#
# [4 rows x 61 columns]
# Query instance (original outcome : 0)
#    Age at recruitment_x  Urea | Instance 0_x  Creatinine | Instance 0_x  \
# 0              -0.22162            -0.167488                   0.002636
#
#    Haemoglobin concentration | Instance 0  \
# 0                                 0.41378
#
#    White blood cell (leukocyte) count | Instance 0_x  Albumin | Instance 0_x  \
# 0                                          -0.066976                0.051291
#
#    Platelet count | Instance 0_x  Platelet distribution width | Instance 0  \
# 0                      -0.014924                                 -0.033741
#
#    Diastolic blood pressure_x  Diastolic blood pressure2_x  ...  \
# 0                    1.575516                     1.390761  ...
#
#        Sex_x_encoded  Ethnic background | Instance 0_encoded  \
# 0  -0.68091419451414                      -0.269760297135527
#
#    Sleeplessness / insomnia | Instance 0_encoded  \
# 0                             1.6387917269255816
#
#    Smoking status | Instance 0_x_encoded  \
# 0                    -0.9791845655101079
#
#    Processed meat intake | Instance 0_encoded  \
# 0                        -0.24456856308405314
#
#    Coffee intake | Instance 0_encoded  \
# 0                -0.48676876808796365
#
#    Alcohol drinker status | Instance 0_x_encoded  \
# 0                           -0.38297092703216873
#
#    Alcohol intake frequency. | Instance 0_encoded  \
# 0                             -1.4287863944230266
#
#    Pace-maker | Instance 0_encoded  target
# 0             -0.17696396228338865       0
#
# [1 rows x 61 columns]
# Diverse Counterfactual set (new outcome: 0)
#    Age at recruitment_x  Urea | Instance 0_x  Creatinine | Instance 0_x  \
# 0              -0.22162            -0.167488                   0.002636
# 1              -0.22162            -0.167488                   0.002636
# 2              -0.22162            -0.167488                   0.002636
# 3              -0.22162            -0.167488                   0.002636
#
#    Haemoglobin concentration | Instance 0  \
# 0                                 0.41378
# 1                                 0.41378
# 2                                 0.41378
# 3                                 0.41378
#
#    White blood cell (leukocyte) count | Instance 0_x  Albumin | Instance 0_x  \
# 0                                          -0.066976                0.051291
# 1                                          -0.066976                0.051291
# 2                                          -0.066976                0.051291
# 3                                          -0.066976                0.051291
#
#    Platelet count | Instance 0_x  Platelet distribution width | Instance 0  \
# 0                      -0.014924                                 -0.033741
# 1                      -0.014924                                 -0.033741
# 2                      -0.014924                                 -0.033741
# 3                      -0.014924                                 -0.033741
#
#    Diastolic blood pressure_x  Diastolic blood pressure2_x  ...  \
# 0                    1.575516                     1.390761  ...
# 1                    1.575516                     1.390761  ...
# 2                    1.575516                     1.390761  ...
# 3                    1.575516                     1.390761  ...
#
#    Sex_x_encoded  Ethnic background | Instance 0_encoded  \
# 0      -0.680914                                -0.26976
# 1      -0.680914                                -0.26976
# 2      -0.680914                                -0.26976
# 3      -0.680914                                -0.26976
#
#    Sleeplessness / insomnia | Instance 0_encoded  \
# 0                                       1.638792
# 1                                       1.638792
# 2                                       1.638792
# 3                                       1.638792
#
#    Smoking status | Instance 0_x_encoded  \
# 0                              -0.979185
# 1                              -0.979185
# 2                              -0.979185
# 3                              -0.979185
#
#    Processed meat intake | Instance 0_encoded  \
# 0                                   -0.244569
# 1                                   -0.244569
# 2                                   -0.244569
# 3                                   -0.244569
#
#    Coffee intake | Instance 0_encoded  \
# 0                           -0.486769
# 1                           -0.486769
# 2                           -0.486769
# 3                           -0.486769
#
#    Alcohol drinker status | Instance 0_x_encoded  \
# 0                                      -0.382971
# 1                                      -0.382971
# 2                                      -0.382971
# 3                                      -0.382971
#
#    Alcohol intake frequency. | Instance 0_encoded  \
# 0                                       -1.428786
# 1                                       -1.428786
# 2                                       -1.428786
# 3                                       -1.428786
#
#    Pace-maker | Instance 0_encoded  target
# 0                        -0.176964       0
# 1                        -0.176964       0
# 2                        -0.176964       0
# 3                        -0.176964       0
#
# [4 rows x 61 columns]
# Query instance (original outcome : 0)
#    Age at recruitment_x  Urea | Instance 0_x  Creatinine | Instance 0_x  \
# 0             -0.056539            -0.283171                   0.216351
#
#    Haemoglobin concentration | Instance 0  \
# 0                                2.291916
#
#    White blood cell (leukocyte) count | Instance 0_x  Albumin | Instance 0_x  \
# 0                                          -0.702642                0.124985
#
#    Platelet count | Instance 0_x  Platelet distribution width | Instance 0  \
# 0                       -0.31369                                  2.635916
#
#    Diastolic blood pressure_x  Diastolic blood pressure2_x  ...  \
# 0                     1.65826                     1.989821  ...
#
#        Sex_x_encoded  Ethnic background | Instance 0_encoded  \
# 0  -0.68091419451414                      -0.269760297135527
#
#    Sleeplessness / insomnia | Instance 0_encoded  \
# 0                             1.6387917269255816
#
#    Smoking status | Instance 0_x_encoded  \
# 0                    -0.9791845655101079
#
#    Processed meat intake | Instance 0_encoded  \
# 0                          -1.021286542549139
#
#    Coffee intake | Instance 0_encoded  \
# 0                  -1.224957433896522
#
#    Alcohol drinker status | Instance 0_x_encoded  \
# 0                           -0.38297092703216873
#
#    Alcohol intake frequency. | Instance 0_encoded  \
# 0                             -1.4287863944230266
#
#    Pace-maker | Instance 0_encoded  target
# 0             -0.17696396228338865       0
#
# [1 rows x 61 columns]
# Diverse Counterfactual set (new outcome: 0)
#    Age at recruitment_x  Urea | Instance 0_x  Creatinine | Instance 0_x  \
# 0             -0.056539            -0.283171                   0.216351
# 1             -0.056539            -0.283171                   0.216351
# 2             -0.056539            -0.283171                   0.216351
# 3             -0.056539            -0.283171                   0.216351
#
#    Haemoglobin concentration | Instance 0  \
# 0                                2.291916
# 1                                2.291916
# 2                                2.291916
# 3                                2.291916
#
#    White blood cell (leukocyte) count | Instance 0_x  Albumin | Instance 0_x  \
# 0                                          -0.702642                0.124985
# 1                                          -0.702642                0.124985
# 2                                          -0.702642                0.124985
# 3                                          -0.702642                0.124985
#
#    Platelet count | Instance 0_x  Platelet distribution width | Instance 0  \
# 0                       -0.31369                                  2.635916
# 1                       -0.31369                                  2.635916
# 2                       -0.31369                                  2.635916
# 3                       -0.31369                                  2.635916
#
#    Diastolic blood pressure_x  Diastolic blood pressure2_x  ...  \
# 0                     1.65826                     1.989821  ...
# 1                     1.65826                     1.989821  ...
# 2                     1.65826                     1.989821  ...
# 3                     1.65826                     1.989821  ...
#
#    Sex_x_encoded  Ethnic background | Instance 0_encoded  \
# 0      -0.680914                                -0.26976
# 1      -0.680914                                -0.26976
# 2      -0.680914                                -0.26976
# 3      -0.680914                                -0.26976
#
#    Sleeplessness / insomnia | Instance 0_encoded  \
# 0                                       1.638792
# 1                                       1.638792
# 2                                       1.638792
# 3                                       1.638792
#
#    Smoking status | Instance 0_x_encoded  \
# 0                              -0.979185
# 1                              -0.979185
# 2                              -0.979185
# 3                              -0.979185
#
#    Processed meat intake | Instance 0_encoded  \
# 0                                   -1.021287
# 1                                   -1.021287
# 2                                   -1.021287
# 3                                   -1.021287
#
#    Coffee intake | Instance 0_encoded  \
# 0                           -1.224957
# 1                           -1.224957
# 2                           -1.224957
# 3                           -1.224957
#
#    Alcohol drinker status | Instance 0_x_encoded  \
# 0                                      -0.382971
# 1                                      -0.382971
# 2                                      -0.382971
# 3                                      -0.382971
#
#    Alcohol intake frequency. | Instance 0_encoded  \
# 0                                       -1.428786
# 1                                       -1.428786
# 2                                       -1.428786
# 3                                       -1.428786
#
#    Pace-maker | Instance 0_encoded  target
# 0                        -0.176964       0
# 1                        -0.176964       0
# 2                        -0.176964       0
# 3                        -0.176964       0
#
# [4 rows x 61 columns]

# %%
dice.cf_examples_list[0].final_cfs_df.to_csv(path_or_buf='src/dice/counterfactuals_LGBM.csv', index=False)

# %%
rias.init_shap_explainer()
rias.calculate_shap_values()
# Out:
# Permutation explainer: 6845it [15:59,  7.10it/s]

# %%
import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
rias.save_rias()
# Out:
# loaded_name model
# loaded_name model
# loaded_name masker
# loaded_name data
# loaded_name max_samples
# loaded_name clustering
# loaded_name link

# %%
new_rias = RIAS.load_rias("rias_checkpoints/EHR-LGBM-2024_05_25-09_29_09.pickle")
# Out:
# loaded_name model
# loaded_name model
# loaded_name masker
# loaded_name data
# loaded_name max_samples
# loaded_name clustering
# loaded_name link

# %%
shap.initjs()
new_rias.report_pred(X_test.iloc[0], 1)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='iHBRPOIG8F1CBFNO6B9M8'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.24205972832625378, "outValue": 0.3247232472324473, "link": "identity", "featureNames": ["Age at recruitment_x", "Urea | Instance 0_x", "Creatinine | Instance 0_x", "Haemoglobin concentration | Instance 0", "White blood cell (leukocyte) count | Instance 0_x", "Albumin | Instance 0_x", "Platelet count | Instance 0_x", "Platelet distribution width | Instance 0", "Diastolic blood pressure_x", "Diastolic blood pressure2_x", "Haematocrit percentage | Instance 0", "Lymphocyte percentage | Instance 0", "Neutrophill percentage | Instance 0", "Red blood cell (erythrocyte) count | Instance 0", "Alanine aminotransferase | Instance 0", "Albumin | Instance 0_y", "Alkaline phosphatase | Instance 0", "Apolipoprotein A | Instance 0", "Apolipoprotein B | Instance 0", "Aspartate aminotransferase | Instance 0", "C-reactive protein | Instance 0", "Calcium | Instance 0", "Cholesterol | Instance 0", "Cystatin C | Instance 0", "Direct bilirubin | Instance 0", "Gamma glutamyltransferase | Instance 0", "Glucose | Instance 0", "Glycated haemoglobin (HbA1c) | Instance 0", "HDL cholesterol | Instance 0", "IGF-1 | Instance 0", "LDL direct | Instance 0", "Lipoprotein A | Instance 0", "Phosphate | Instance 0", "Total bilirubin | Instance 0", "Total protein | Instance 0", "Triglycerides | Instance 0", "Summed MET minutes per week for all activity | Instance 0", "Systolic blood pressure", "Systolic blood pressure2", "Pulse rate", "Pulse rate2", "CKMT1A_CKMT1B;Creatine kinase U-type", "NTproBNP;N-terminal prohormone of brain natriuretic peptide", "NBL1;Neuroblastoma suppressor of tumorigenicity 1", "LGALS3;Galectin-3", "Urate | Instance 0", "Vitamin D | Instance 0", "Microalbumin in urine | Instance 0", "Standing height | Instance 0", "Weight | Instance 0", "Body mass index (BMI) | Instance 0", "Sex_x_encoded", "Ethnic background | Instance 0_encoded", "Sleeplessness / insomnia | Instance 0_encoded", "Smoking status | Instance 0_x_encoded", "Processed meat intake | Instance 0_encoded", "Coffee intake | Instance 0_encoded", "Alcohol drinker status | Instance 0_x_encoded", "Alcohol intake frequency. | Instance 0_encoded", "Pace-maker | Instance 0_encoded"], "features": {"0": {"effect": -0.00449298237612894, "value": -1.8724323683421904}, "1": {"effect": -0.0006746930346887073, "value": -0.48329583434706225}, "2": {"effect": 0.006250977999014251, "value": -0.577453884893731}, "3": {"effect": 0.0029612339880851525, "value": -0.09112095091579565}, "4": {"effect": 0.0005964383297449652, "value": -0.6726346788116159}, "5": {"effect": 0.0011416986636082448, "value": -0.5684393442082741}, "6": {"effect": 0.00033013712241654336, "value": -1.0528703077970492}, "7": {"effect": -0.0032898733163106986, "value": 1.2685772796297046}, "8": {"effect": 0.01180551894077174, "value": 0.5825935903260328}, "9": {"effect": -0.0027301941925917533, "value": 0.7917013730598957}, "10": {"effect": -0.004824701247807425, "value": 0.06215400945894196}, "11": {"effect": 0.004928381517997207, "value": 0.6272619489824783}, "12": {"effect": -0.00020295111287757864, "value": -0.1669760489199686}, "13": {"effect": 0.002170816750091495, "value": 0.19559338820973152}, "14": {"effect": 0.0013240500648249859, "value": -0.7073738611848638}, "15": {"effect": -0.0013522081419947256, "value": -0.9984221135315362}, "16": {"effect": -9.576395570196766e-05, "value": -0.01665716310480464}, "17": {"effect": 0.0017299522905801189, "value": 0.9082395641273474}, "18": {"effect": 7.651400043412818e-05, "value": 0.31314477137093566}, "19": {"effect": 0.00010259890208203296, "value": -0.4226776251130521}, "20": {"effect": -0.001797596773872711, "value": -0.3380518794454024}, "21": {"effect": -0.0004532153856721191, "value": -0.01785249887885558}, "22": {"effect": 0.002481908222798434, "value": 1.1244147043263046}, "23": {"effect": 0.0009143084810716885, "value": -0.40020148994995475}, "24": {"effect": 0.00995530514772640 ...
#     document.getElementById('iHBRPOIG8F1CBFNO6B9M8')
#   );
# </script>

# %%
import shap
shap_values = rias.shap_explainer(X_test)
shap.plots.beeswarm(shap_values[:, :, 1])
# Out:
# Permutation explainer: 1713it [22:37,  1.25it/s]

# %%
shap.dependence_plot("Age at recruitment_x", shap_values.values[:, :, 0], X_test, interaction_index=3)

# %%
shap.plots.scatter(shap_values[:, "Urea | Instance 0_x", 1], color=shap_values[:,:,1])
